# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xp = np.array([0,6])
yp = np.array([0,250])

plt.plot(xp,yp) # -> plot() function is used to draw point in a diagram.
plt.show()

# %%
xp = np.array([1,8]) # => The x-axis is the horizontal axis.
yp = np.array([3,10]) # => The y-axis is the vertical axis.

plt.plot(xp,yp)
plt.show()

# %%
yp = np.array([3,8,1,10])


plt.plot(yp, marker='o') #marker
plt.plot(yp, marker='s') #Quadrilateral
plt.plot(yp, marker='^') #Triangle
plt.plot(yp, marker='*') #star

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

# plt.plot(ypoints, linestyle = 'dotted') #dot graph
# plt.plot(ypoints, linestyle = 'dashed')#dash graph
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)

plt.xlabel("X Axis")
plt.ylabel("Y Axis")
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
#plot 1

x1 = np.array([0,1,2,3])
y1 = np.array([3,8,1,10])

plt.subplot(1,2,1)
plt.plot(x1,y1)

#plot 2

x2 = np.array([0,1,2,3])
y2 = np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x2,y2)

plt.show()

#subplot() function you can draw multiple plots in one figure

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y) #산점도 그래프 생성
plt.show()

#scatter() function to draw a scatter plot.
#The scatter() function plots one dot for each observation.
# It needs two arrays of the same length, one for the values of the x-axis,
# and one for values on the y-axis

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y) #Bar 그래프 생성
plt.show()

# %%
x = np.random.normal(170, 10, 250)

# print(x)

plt.hist(x) #히스토그램 그래프 생성
plt.show()

# %%
y = np.array([35,25,25,15])

plt.pie(y) #원형 그래프 생성
plt.show()

# %%
fig = plt.figure()             # an empty figure with no Axes
fig, ax = plt.subplots()       # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
# a figure with one Axes on the left, and two on the right:
fig, axs = plt.subplot_mosaic([['left', 'right_top'],['left', 'right_bottom']])

# %%
b = np.matrix([[1,2,], [3,4]])

b_asarray = np.asarray(b)

np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %%
x = np.linspace(0, 2, 100)  # Sample data.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.plot(x, x, label='linear')  # Plot some data on the Axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the Axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the Axes.
ax.set_ylabel('y label')  # Add a y-label to the Axes.
ax.set_title("Simple Plot")  # Add a title to the Axes.
ax.legend()  # Add a legend.

# %%
x = np.linspace(0, 2, 100)  # Sample data.

plt.figure(figsize=(5, 2.7), layout='constrained')
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) Axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()
